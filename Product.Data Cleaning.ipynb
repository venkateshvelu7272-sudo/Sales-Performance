# %%
import pandas as pd
import numpy as np

# %%
Product_Details= pd.read_csv(r"C:\Users\venka\Downloads\SQL Project\gold.dim_products.csv")

# %%
Product_Details
# Out:
#      product_key  product_id product_number               product_name  \
# 0              1         210     FR-R92B-58  HL Road Frame - Black- 58
# 1              2         211     FR-R92R-58    HL Road Frame - Red- 58
# 2              3         348     BK-M82B-38     Mountain-100 Black- 38
# 3              4         349     BK-M82B-42     Mountain-100 Black- 42
# 4              5         350     BK-M82B-44     Mountain-100 Black- 44
# ..           ...         ...            ...                        ...
# 290          291         530        TT-T092          Touring Tire Tube
# 291          292         473      VE-C304-L            Classic Vest- L
# 292          293         472      VE-C304-M            Classic Vest- M
# 293          294         471      VE-C304-S            Classic Vest- S
# 294          295         477        WB-H098      Water Bottle - 30 oz.
#
#     category_id     category        subcategory maintenance  cost  \
# ...

# %%
Product_Details.head()
# Out:
#    product_key  product_id product_number               product_name  \
# 0            1         210     FR-R92B-58  HL Road Frame - Black- 58
# 1            2         211     FR-R92R-58    HL Road Frame - Red- 58
# 2            3         348     BK-M82B-38     Mountain-100 Black- 38
# 3            4         349     BK-M82B-42     Mountain-100 Black- 42
# 4            5         350     BK-M82B-44     Mountain-100 Black- 44
#
#   category_id    category     subcategory maintenance  cost product_line  \
# 0       CO_RF  Components     Road Frames         Yes     0         Road
# 1       CO_RF  Components     Road Frames         Yes     0         Road
# 2       BI_MB       Bikes  Mountain Bikes         Yes  1898     Mountain
# 3       BI_MB       Bikes  Mountain Bikes         Yes  1898     Mountain
# 4       BI_MB       Bikes  Mountain Bikes         Yes  1898     Mountain
#
#   start_date
# 0   7/1/2003
# 1   7/1/2003
# 2   7/1/2011
# 3   7/1/2011
# 4   7/1/2011

# %%
Product_Details.shape
# Out:
# (295, 11)

# %%
Product_Details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_key     295 non-null    int64
#  1   product_id      295 non-null    int64
#  2   product_number  295 non-null    object
#  3   product_name    295 non-null    object
#  4   category_id     295 non-null    object
#  5   category        288 non-null    object
#  6   subcategory     288 non-null    object
#  7   maintenance     288 non-null    object
#  8   cost            295 non-null    int64
#  9   product_line    278 non-null    object
#  10  start_date      295 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 25.5+ KB

# %%
Product_Details.columns = (
    Product_Details.columns
    .str.strip()
    .str.lower()
    .str.replace(" ","_")
)

# %%
Product_Details
# Out:
#      product_key  product_id product_number               product_name  \
# 0              1         210     FR-R92B-58  HL Road Frame - Black- 58
# 1              2         211     FR-R92R-58    HL Road Frame - Red- 58
# 2              3         348     BK-M82B-38     Mountain-100 Black- 38
# 3              4         349     BK-M82B-42     Mountain-100 Black- 42
# 4              5         350     BK-M82B-44     Mountain-100 Black- 44
# ..           ...         ...            ...                        ...
# 290          291         530        TT-T092          Touring Tire Tube
# 291          292         473      VE-C304-L            Classic Vest- L
# 292          293         472      VE-C304-M            Classic Vest- M
# 293          294         471      VE-C304-S            Classic Vest- S
# 294          295         477        WB-H098      Water Bottle - 30 oz.
#
#     category_id     category        subcategory maintenance  cost  \
# ...

# %%
Product_Details.isnull().sum()
# Out:
# product_key        0
# product_id         0
# product_number     0
# product_name       0
# category_id        0
# category           7
# subcategory        7
# maintenance        7
# cost               0
# product_line      17
# start_date         0
# dtype: int64

# %%
cols_with_nulls = ['category', 'subcategory', 'maintenance', 'product_line'] #list of missing value columns
#filling missing value with unknown
Product_Details[cols_with_nulls] = Product_Details[cols_with_nulls].fillna("Unknown")

# %%
Product_Details.isnull().sum()
# Out:
# product_key       0
# product_id        0
# product_number    0
# product_name      0
# category_id       0
# category          0
# subcategory       0
# maintenance       0
# cost              0
# product_line      0
# start_date        0
# dtype: int64

# %%
Product_Details
# Out:
#      product_key  product_id product_number               product_name  \
# 0              1         210     FR-R92B-58  HL Road Frame - Black- 58
# 1              2         211     FR-R92R-58    HL Road Frame - Red- 58
# 2              3         348     BK-M82B-38     Mountain-100 Black- 38
# 3              4         349     BK-M82B-42     Mountain-100 Black- 42
# 4              5         350     BK-M82B-44     Mountain-100 Black- 44
# ..           ...         ...            ...                        ...
# 290          291         530        TT-T092          Touring Tire Tube
# 291          292         473      VE-C304-L            Classic Vest- L
# 292          293         472      VE-C304-M            Classic Vest- M
# 293          294         471      VE-C304-S            Classic Vest- S
# 294          295         477        WB-H098      Water Bottle - 30 oz.
#
#     category_id     category        subcategory maintenance  cost  \
# ...

# %%
Product_Details.to_csv("cleaned_product_details.csv", index=False)
